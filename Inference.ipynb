# %% [markdown]
# # Permasalahan
#
# ![alt text](image.png)

# %% [markdown]
# # Solusi

# %% [markdown]
# ## Alphageometry

# %% [markdown]
# Menetapkan Variabel Lingkungan untuk Path

# %%
# !MELIAD_PATH=meliad_lib/meliad

# %% [markdown]
# Menambahkan Path ke PYTHONPATH

# %%
# !export PYTHONPATH=$PYTHONPATH:meliad_lib/meliad

# %% [markdown]
# Menetapkan Variabel DATA

# %%
# !DATA=ag_ckpt_vocab

# %% [markdown]
# Menetapkan Argumen DDAR

# %%
# !DDAR_ARGS=(--defs_file=$(pwd)/defs.txt, --rules_file=$(pwd)/rules.txt);

# %% [markdown]
# Menetapkan Parameter Numerik dan Menetapkan Argumen Pencarian (SEARCH_ARGS)

# %%
BATCH_SIZE=2
BEAM_SIZE=2
DEPTH=2

# !SEARCH_ARGS=(--beam_size=2, --search_depth=2)

# %% [markdown]
# Menetapkan Argumen untuk Model Bahasa (LM_ARGS)

# %%
# !LM_ARGS=(--ckpt_path=$DATA --vocab_path=$DATA/geometry.757.model --gin_search_paths=$MELIAD_PATH/transformer/configs,$(pwd) --gin_file=base_htrans.gin --gin_file=size/medium_150M.gin --gin_file=options/positions_t5.gin --gin_file=options/lr_cosine_decay.gin --gin_file=options/seq_1024_nocache.gin --gin_file=geometry_150M_generate.gin --gin_param=DecoderOnlyLanguageModelGenerate.output_token_losses=True --gin_param=TransformerTaskConfig.batch_size=$BATCH_SIZE --gin_param=TransformerTaskConfig.sequence_length=128 --gin_param=Trainer.restore_state_variables=False);

# %% [markdown]
# Menjalankan Modul Alphageometry

# %%
# !python -m alphageometry --alsologtostderr --problems_file=$(pwd)/imo_ag_30.txt --problem_name=translated_imo_2000_p1 --mode=ddar "${DDAR_ARGS[@]}"
# Out:
# /home/edwinjaya/miniconda3/envs/deepmind/lib/python3.10/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/edwinjaya/miniconda3/envs/deepmind/lib/python3.10/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/edwinjaya/miniconda3/envs/deepmind/lib/python3.10/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# 2025-04-12 13:40:49.585988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/edwinjaya/miniconda3/envs/deepmind/lib/python3.10/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/edwinjaya/miniconda3/envs/deepmind/lib/python3.10/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/edwinjaya/miniconda3/envs/deepmind/lib/python3.10/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# 2025-04-12 13:40:53.177038: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# I0412 13:40:53.214161 140403406661120 graph.py:498] translated_imo_2000_p1
# I0412 13:40:53.214325 140403406661120 graph.py:499] a b = segment a b; g1 = on_tline g1 a a b; g2 = on_tline g2 b b a; m = on_circle m g1 a, on_circle m g2 b; n = on_circle n g1 a, on_circle n g2 b; c = on_pline c m a b, on_circle c g1 a; d = on_pline d m a b, on_circle d g2 b; e = on_line e a c, on_line e b d; p = on_line p a n, on_line p c d; q = on_line q b n, on_line q c d ? cong e p e q
# I0412 13:40:54.406982 140403406661120 ddar.py:60] Depth 1/1000 time = 1.1511552333831787
# I0412 13:40:56.993970 140403406661120 ddar.py:60] Depth 2/1000 time = 2.5867502689361572
# I0412 13:41:00.228694 140403406661120 ddar.py:60] Depth 3/1000 time = 3.2345383167266846
# I0412 13:41:05.084338 140403406661120 ddar.py:60] Depth 4/1000 time = 4.855412006378174
# I0412 13:41:11.199103 140403406661120 ddar.py:60] Depth 5/1000 time = 6.114534616470337
# I0412 13:41:11.223718 140403406661120 alphageometry.py:191]
# ==========================
#  * From theorem premises:
# A B G1 G2 M N C D E P Q : Points
# AG_1 ⟂ AB [00]
# BA ⟂ G_2B [01]
# G_1M = G_1A [02]
# G_2M = G_2B [03]
# G_1N = G_1A [04]
# G_2N = G_2B [05]
# CM ∥ AB [06]
# G_1C = G_1A [07]
# ∠CAN = ∠CAN [08]
# DM ∥ AB [09]
# G_2D = G_2B [10]
# ∠DBN = ∠DBN [11]
# E,C,A are collinear [12]
# B,D,E are collinear [13]
# NA:PA = NA:PA [14]
# P,C,D are collinear [15]
# P,N,A are collinear [16]
# B,N,Q are collinear [17]
# C,D,Q are collinear [18]
#
#  * Auxiliary Constructions:
# : Points
#
#
#  * Proof steps:
# 001. CM ∥ AB [06] & DM ∥ AB [09] ⇒  MD ∥ MC [19]
# 002. MD ∥ MC [19] ⇒  C,D,M are collinear [20]
# 003. G_1M = G_1A [02] & G_1N = G_1A [04] ⇒  G_1 is the circumcenter of \Delta AMN [21]
# 004. G_1 is the circumcenter of \Delta AMN [21] & AG_1 ⟂ AB [00] ⇒  ∠BAM = ∠ANM [22]
# 005. G_1 is the circumcenter of \Delta AMN [21] & AG_1 ⟂ AB [00] ⇒  ∠BAN = ∠AMN [23]
# 006. C,D,M are collinear [20] & P,C,D are collinear [15] & ∠ANM = ∠BAM [22] & DM ∥ AB [09] ⇒  ∠ANM = ∠PMA [24]
# 007. C,D,M are collinear [20] & P,C,D are collinear [15] & P,N,A are collinear [16] & ∠AMN = ∠BAN [23] & DM ∥ AB [09] ⇒  ∠AMN = ∠MPA [25]
# 008. ∠ANM = ∠PMA [24] & ∠AMN = ∠MPA [25] (Similar Triangles)⇒  AN:AM = AM:AP [26]
# 009. G_1N = G_1A [04] & G_1C = G_1A [07] & G_1M = G_1A [02] ⇒  C,N,A,M are concyclic [27]
# 010. G_1C = G_1A [07] & G_1N = G_1A [04] ⇒  G_1 is the circumcenter of \Delta ACN [28]
# 011. G_1 is the circumcenter of \Delta ACN [28] & AG_1 ⟂ AB [00] ⇒  ∠CAB = ∠CNA [29]
# 012. C,D,M are collinear [20] & ∠CNA = ∠CAB [29] & DM ∥ AB [09] ⇒  ∠CNA = ∠ACM [30]
# 013. C,N,A,M are concyclic [27] & ∠CNA = ∠ACM [30] ⇒  CA = AM [31]
# 014. G_1C = G_1A [07] & G_1M = G_1A [02] ⇒  G_1 is the circumcenter of \Delta ACM [32]
# 015. G_1 is the circumcenter of \Delta ACM [32] & AG_1 ⟂ AB [00] ⇒  ∠BAC = ∠AMC [33]
# 016. E,A,C are collinear [12] & ∠BAC = ∠AMC [33] & CM ∥ AB [06] ⇒  ∠EAB = ∠BAM [34]
# 017. G_2D = G_2B [10] & G_2M = G_2B [03] ⇒  G_2 is the circumcenter of \Delta BDM [35]
# 018. G_2 is the circumcenter of \Delta BDM [35] & G_2B ⟂ BA [01] ⇒  ∠ABD = ∠BMD [36]
# 019. B,D,E are collinear [13] & ∠ABD = ∠BMD [36] & DM ∥ AB [09] ⇒  ∠EBA = ∠ABM [37]
# 020. ∠EAB = ∠BAM [34] & ∠EBA = ∠ABM [37] (Similar Triangles)⇒  AE = AM [38]
# 021. ∠EAB = ∠BAM [34] & ∠EBA = ∠ABM [37] (Similar Triangles)⇒  BE = BM [39]
# 022. AN:AM = AM:AP [26] & CA = AM [31] & AE = AM [38] ⇒  AE:AN = AP:AE [40]
# 023. E,A,C are collinear [12] & P,N,A are collinear [16] & ∠CAN = ∠CAN [08] ⇒  ∠EAN = ∠EAP [41]
# 024. AE:AN = AP:AE [40] & ∠EAN = ∠EAP [41] (Similar Triangles)⇒  EA:NE = PA:PE [42]
# 025. G_2M = G_2B [03] & G_2D = G_2B [10] & G_2N = G_2B [05] ⇒  B,D,N,M are concyclic [43]
# 026. B,D,N,M are concyclic [43] ⇒  ∠DBN = ∠DMN [44]
# 027. C,N,A,M are concyclic [27] ⇒  ∠CAN = ∠CMN [45]
# 028. E,A,C are collinear [12] & B,D,E are collinear [13] & ∠DBN = ∠DMN [44] & DM ∥ AB [09] & ∠CAN = ∠CMN [45] & CM ∥ AB [06] ⇒  ∠EAN = ∠EBN [46]
# 029. ∠EAN = ∠EBN [46] ⇒  B,E,N,A are concyclic [47]
# 030. B,E,N,A are concyclic [47] ⇒  ∠BNE = ∠BAE [48]
# 031. B,E,N,A are concyclic [47] ⇒  ∠BEN = ∠BAN [49]
# 032. B,N,Q are collinear [17] & C,D,M are collinear [20] & P,C,D are collinear [15] & ∠BAC = ∠AMC [33] & CM ∥ AB [06] & ∠BNE = ∠BAE [48] & E,C,A are collinear [12] & DM ∥ AB [09] ⇒  ∠ENQ = ∠PMA [50]
# 033. G_2N = G_2B [05] & G_2M = G_2B [03] ⇒  G_2 is the circumcenter of \Delta BNM [51]
# 034. G_2 is the circumcenter of \Delta BNM [51] & G_2B ⟂ BA [01] ⇒  ∠MBA = ∠MNB [52]
# 035. G_2 is the circumcenter of \Delta BNM [51] & G_2B ⟂ BA [01] ⇒  ∠NBA = ∠NMB [53]
# 036. C,D,M are collinear [20] & C,D,Q are collinear [18] & ∠MBA = ∠MNB [52] & DM ∥ AB [09] ⇒  ∠BMQ = ∠MNB [54]
# 037. B,N,Q are collinear [17] & C,D,M are collinear [20] & C,D,Q are collinear [18] & ∠NBA = ∠NMB [53] & DM ∥ AB [09] ⇒  ∠BQM = ∠NMB [55]
# 038. ∠BMQ = ∠MNB [54] & ∠BQM = ∠NMB [55] (Similar Triangles)⇒  BM:BQ = BN:BM [56]
# 039. G_2D = G_2B [10] & G_2N = G_2B [05] ⇒  G_2 is the circumcenter of \Delta BDN [57]
# 040. G_2 is the circumcenter of \Delta BDN [57] & G_2B ⟂ BA [01] ⇒  ∠ABD = ∠BND [58]
# 041. C,D,M are collinear [20] & ∠BND = ∠ABD [58] & DM ∥ AB [09] ⇒  ∠BND = ∠MDB [59]
# 042. B,D,N,M are concyclic [43] & ∠BND = ∠MDB [59] ⇒  BD = MB [60]
# 043. BM:BQ = BN:BM [56] & BD = MB [60] & BE = BM [39] ⇒  BE:BN = BQ:BE [61]
# 044. B,D,E are collinear [13] & B,N,Q are collinear [17] & ∠DBN = ∠DBN [11] ⇒  ∠EBN = ∠EBQ [62]
# 045. BE:BN = BQ:BE [61] & ∠EBN = ∠EBQ [62] (Similar Triangles)⇒  ∠BEN = ∠EQB [63]
# 046. B,N,Q are collinear [17] & C,D,M are collinear [20] & P,C,D are collinear [15] & P,N,A are collinear [16] & ∠BEN = ∠BAN [49] & B,D,E are collinear [13] & ∠BEN = ∠EQB [63] & DM ∥ AB [09] ⇒  ∠EQN = ∠MPA [64]
# 047. ∠ENQ = ∠PMA [50] & ∠EQN = ∠MPA [64] (Similar Triangles)⇒  EN:AM = EQ:AP [65]
# 048. EA:NE = PA:PE [42] & EN:AM = EQ:AP [65] & AE = AM [38] ⇒  PA:EQ = PA:PE [66]
# 049. NA:PA = NA:PA [14] & PA:EQ = PA:PE [66] ⇒  EQ = PE
# ==========================
#
# /mnt/d/College/Google/Deepmind/Local/alphageometry/numericals.py:1238: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show(block=block)

# %% [markdown]
# ## Jawaban Medalist Emas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# ![image.png](attachment:image.png)
